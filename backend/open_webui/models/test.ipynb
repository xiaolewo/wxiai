# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from models.kling_lip_sync import KlingLipSyncTable
#       4 a = KlingLipSyncTable()
#
# File c:\Users\29836\Desktop\wxiai-main_2\backend\open_webui\models\models.py:5
#       2 import time
#       3 from typing import Optional
# ----> 5 from open_webui.internal.db import Base, JSONField, get_db
#       6 from open_webui.env import SRC_LOG_LEVELS
#       8 from open_webui.models.users import Users, UserResponse
#
# ModuleNotFoundError: No module named 'open_webui'
